# %% [markdown]
# <a href="https://colab.research.google.com/github/P-yi-6/Data-science-wk1/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

Basic_NBA_Players_Data = np.array([
    ['Player', 'FG%', '3P%', 'Total FGM'],
    ['LeBron James', '0.540', '0.410', '685'],
    ['Stephen Curry', '0.450', '0.408', '598'],
    ['Kyrie Irving', '0.497', '0.411', '563']
],)

print(Basic_NBA_Players_Data)
# Out:
# [['Player' 'FG%' '3P%' 'Total FGM']
#  ['LeBron James' '0.540' '0.410' '685']
#  ['Stephen Curry' '0.450' '0.408' '598']
#  ['Kyrie Irving' '0.497' '0.411' '563']]
